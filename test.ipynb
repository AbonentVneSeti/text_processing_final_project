# %%
# Ячейка 1: Загрузка модели
from utils import load_config
from models.model_use import load_model, generate_paraphrases

config = load_config("config.yaml")
model = load_model(
    config["model_name"],
    config["model_config"],
    checkpoint_path=config["trainer_config"]["output_dir"]
)
print("Model loaded")
# Out:
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Model loaded

# %%
# Ячейка 2: Проверка на готовых предложениях
test_sentences = [
    "сегодня хорошая погода.",
    "искусственный интеллект меняет мир.",
    "я люблю читать книги по вечерам.",
    "машинное обучение требует больших данных.",
    "кошка сидит на подоконнике и смотрит в окно.",
    "перефразирование помогает улучшить текст.",
    "экономика страны растёт благодаря новым технологиям.",
    "студенты сдают экзамены в конце семестра."
]

paraphrases = model.generate(test_sentences)

print("Ручная проверка:\n")
for orig, para in zip(test_sentences, paraphrases):
    print(f"Оригинал : {orig}")
    print(f"Парафраз : {para}")
    print("-" * 50)
# Out:
# [transformers] The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Ручная проверка
#
# Оригинал : сегодня хорошая погода.
# Парафраз : сегодня хорошая погода.
# --------------------------------------------------
# Оригинал : искусственный интеллект меняет мир.
# Парафраз : искусственный компьютер меняет мир.
# --------------------------------------------------
# Оригинал : я люблю читать книги по вечерам.
# Парафраз : я люблю читать книги по вечером.
# --------------------------------------------------
# Оригинал : машинное обучение требует больших данных.
# Парафраз : машинное обучить - очень много данных.
# --------------------------------------------------
# Оригинал : кошка сидит на подоконнике и смотрит в окно.
# Парафраз : кошка смотрит в окно.
# --------------------------------------------------
# Оригинал : перефразирование помогает улучшить текст.
# Парафраз : перефразирование помогает улучшить книгу.
# --------------------------------------------------
# Оригинал : экономика страны растёт благодаря новым технологиям.
# Парафраз : экономика страны растёт для новых опытов.
# --------------------------------------------------
# Оригинал : студенты сдают экзамены в конце семестра.
# Парафраз : студенты сдают экзамены в конце семестра.
# --------------------------------------------------
